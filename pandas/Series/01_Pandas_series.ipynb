# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series from lists

# %%
# string
country = ['India','pakistan','USA','Nepal','srilanka']
pd.Series(country)
# Out:
# 0       India
# 1    pakistan
# 2         USA
# 3       Nepal
# 4    srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,23,4,5]
pd.Series(runs)
# Out:
# 0    13
# 1    24
# 2    56
# 3    23
# 4     4
# 5     5
# dtype: int64

# %%
# custom index
marks = [64,34,55,67,100]
subject = ['maths','science','english','hindi','biology']

pd.Series(marks,index=subject)
# Out:
# maths       64
# science     34
# english     55
# hindi       67
# biology    100
# dtype: int64

# %%
# set a name
marks = pd.Series(marks, index=subject, name='Aditya marks')
marks
# Out:
# maths       64
# science     34
# english     55
# hindi       67
# biology    100
# Name: Aditya marks, dtype: int64

# %% [markdown]
# ## Series from dict

# %%
marks = {
    'maths' :67,
    'english' :57,
    'science' :89,
    'hindi' :100
}
marks_Series = pd.Series(marks,name="Aditya  marks")
marks_Series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Aditya  marks, dtype: int64

# %% [markdown]
# ## Series Attributes

# %%
# Size
marks_Series.size
# Out:
# 4

# %%
# dtype
marks_Series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_Series.name
# Out:
# 'Aditya  marks'

# %%
# is_unique
marks_Series.is_unique
# Out:
# True

# %%
# index
marks_Series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
# values
marks_Series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# ## Series using read_csv

# %%
# with one column
subs =pd.read_csv('/content/subs.csv').iloc[:, 0]
subs
#squeeze = True is are not support so use iloc library
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 cols
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').iloc[:,0]
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col='movie').iloc[:,0]
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## Serirs methods

# %%
# head
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
# Tail
vk.tail(5)
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# sample
movies.sample(5)
# Out:
# movie
# Thugs of Hindostan        Aamir Khan
# Hawayein                  Babbu Mann
# Loveshhuda            Girish Taurani
# Chingaari               Sushmita Sen
# Woh Lamhe...          Kangana Ranaut
# Name: lead, dtype: object

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values -> inplace
vk.sort_values(ascending=False).head(5).values[0]
# Out:
# np.int64(113)

# %%
# sort_index -> inplace -> movies
movies.sort_index(inplace = True)
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Series Maths methods

# %%
# count
vk.count()
# Out:
# np.int64(215)

# %%
# sum -> product
subs.sum()
# Out:
# np.int64(49510)

# %%
# mean ->median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(vk.var())
# Out:
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: object
# 62.67502303725269
# 688.0024777222344

# %%
# min / max
print(subs.max())
print(subs.min())
# Out:
# 396
# 33

# %%
# describe
subs.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %% [markdown]
# ## Series indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,57,58,79,9])
x.loc[5]
# Out:
# np.int64(57)

# %%
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.iloc[4]
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# ## Slicing

# %%
# slicing
vk[5:16]
# Out:
# match_no
# 6      9
# 7     34
# 8      0
# 9     21
# 10     3
# 11    10
# 12    38
# 13     3
# 14    11
# 15    50
# 16     2
# Name: runs, dtype: int64

# %%
# negative slicing
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[::2]
# Out:
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: The Evil Returns           Vicky Ahuja
# 2 States (2014 film)            Arjun Kapoor
# 3 A.M. (2014 film)             Salil Acharya
# 3 Idiots                          Aamir Khan
#                                   ...
# Zero (2018 film)              Shah Rukh Khan
# Zila Ghaziabad                  Vivek Oberoi
# Zindaggi Rocks                  Sushmita Sen
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zokkomon                     Darsheel Safary
# Name: lead, Length: 750, dtype: object

# %%
# fancy indexing
vk[[1,3,4,5]]
# Out:
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels -> fancy indexing
movies['1920: London']
# Out:
# 'Sharman Joshi'

# %% [markdown]
# ## Editing Series

# %%
# using indexing
marks_Series[1] = 100
marks_Series
# Out:
# /tmp/ipykernel_1124/2898719407.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_Series[1] = 100
# maths       67
# english    100
# science     89
# hindi      100
# Name: Aditya  marks, dtype: int64

# %%
# what if an index does not exist
marks_Series['sst'] = 100
marks_Series
# Out:
# maths       67
# english    100
# science     89
# hindi      100
# sst        100
# Name: Aditya  marks, dtype: int64

# %%
# slicing through
marks_Series[2:4] = [67,90]
marks_Series
# Out:
# maths       67
# english    100
# science     67
# hindi       90
# sst        100
# Name: Aditya  marks, dtype: int64

# %%
# fancy slicing
marks_Series[[0,3,4]] = [0,0,0]
marks_Series
# Out:
# /tmp/ipykernel_1124/2339270688.py:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   marks_Series[[0,3,4]] = [0,0,0]
# maths        0
# english    100
# science     67
# hindi        0
# sst          0
# Name: Aditya  marks, dtype: int64

# %%
# using index label
movies['Zindagi 50-50'] = 'Alia bhat'
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                        Alia bhat
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# ## Series with python functonalities

# %%
# len/dir/sorted/max/min
print(len(subs))
print(dir(subs))
print(sorted(subs))
print(max(subs))
print(min(subs))
# Out:
# 365
# ...

# %%
# type conversion
list(marks_Series)
# Out:
# [0, 100, 67, 0, 0]

# %%
dict(marks_Series)
# Out:
# {'maths': np.int64(0),
#  'english': np.int64(100),
#  'science': np.int64(67),
#  'hindi': np.int64(0),
#  'sst': np.int64(0)}

# %%
# membership operator   like isin
'Zindagi 50-50' in movies
# Out:
# True

# %%
# Arithmetic operators (Broadcasting)
100 - marks_Series
# Out:
# maths      100
# english      0
# science     33
# hindi      100
# sst        100
# Name: Aditya  marks, dtype: int64

# %%
# Relational operators
vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ## Boolean indexing on series

# %%
# find no of 50's scored by kohli
vk[vk >=50].size
# Out:
# 50

# %%
# find number of ducks
vk[vk == 0].size
# Out:
# 9

# %%
# count number of day when i had than 200 subs a day
subs[subs > 200].size
# Out:
# 59

# %%
# find actors who have done more than 20 movies
num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# ## ploting Graphs On Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
movies.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='lead'>

# %%
vk.value_counts().head(20).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Some imp Series method

# %%
# astype
# between
# clip
# drop_duplicates
# isnull
# dropna
# fillna
# isin
# apply
# copy

# %%
vk
import sys
sys.getsizeof(vk)
# Out:
# 11768

# %%
# astype
sys.getsizeof(vk.astype('int16'))
# Out:
# 10478

# %%
# between
vk[vk.between(51,99)].size
# Out:
# 43

# %%
# clip
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates
temp = [1,1,1,2,3,3,4,5]
temp = pd.Series(temp)
temp
# Out:
# 0    1
# 1    1
# 2    1
# 3    2
# 4    3
# 5    3
# 6    4
# 7    5
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 2    1
# 3    2
# 5    3
# 6    4
# 7    5
# dtype: int64

# %%
vk.duplicated().sum()
# Out:
# np.int64(137)

# %%
# isnull
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.size
# Out:
# 10

# %%
temp.count()
# Out:
# np.int64(7)

# %%
temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna
temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna
temp.fillna(temp.mean())
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk[vk.isin([49,50])]
# Out:
# match_no
# 15     50
# 86     49
# 182    50
# Name: runs, dtype: int64

# %%
# apply
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                        Alia bhat
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %%
movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# 1920 (film)                 RAJNIESH
# 1920: London                 SHARMAN
# 1920: The Evil Returns         VICKY
# 1971 (2007 film)               MANOJ
# 2 States (2014 film)           ARJUN
#                               ...
# Zindagi 50-50                   ALIA
# Zindagi Na Milegi Dobara     HRITHIK
# Zindagi Tere Naam             MITHUN
# Zokkomon                    DARSHEEL
# Zor Lagaa Ke...Haiya!         MEGHAN
# Name: lead, Length: 1500, dtype: object

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.apply(lambda x:'good day'
           if x > subs.mean()
           else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
# copy

vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new = vk.head().copy()

# %%
new[1] = 100

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64
